# %% [markdown]
# # Chapter 2. Generating Datasets From Selected Variables

# %% [markdown]
# To make things easier, 15 variables have been selected from the acs database. Following are the 15 variables with their corresponding names:
#
# 1. **Over 65 years old population (age)**
# 2. **Education Attainment (education):**
#     * Below 9th grade
#     * Some highschool
#     * Some college
#     * Advanced Degree
# 3. **Civil Employment (employment):**
#     * Employed
#     * Unemployed
# 4. **Ethnicity (ethnicity):**
#     * Hispanic or Latino
#     * Not Hispanic or Latino
# 5. **Rent to Income Ratio (rent_to_income):**
#     * Less than 30 percent
#     * Greater than 30 percent
# 6. **Housing tenure (tenure):**
#     * Renter occupied
#     * Owner occupied
# 7. **Housing  Vacancy (vacancy):**
#     * Sold, not occupied
#     * For seasonal, recreational, or occuational use
#     * For sale only
#     * Rented, not occupied
#     * For rent
#     * Other vacant
#     * For migrant workers
# 8. **Years houses built (years):**
#     * Built 1940 to 1949
#     * ...
#     * Built 2014 or later
# 9. **Median Income to Poverty Level Income (poverty):**
#     * >2x_poverty: estimate of people whose income is greater than twice of the poverty level income
#     * >poverty: estimate of people whose income is between the poverty level and the twice of the poverty level
#     * <poverty: estimate of people earning less than the poverty level
# 10. **Insurance Coverage (insurance):**
#     * With health insurance coverage
#     * No health insurance coverage
# 11. **Nativity (nativitiy):**
#     * Native
#     * Foreign-Born
# 12. **Number of Vehicles (means):**
#     * No vehicle
#     * >1 vehicle : at least one vehicle
# 13. **Commuting Time (travel):**
#     * Less than 5 minutes
#     * ...
#     * 90 or more minutes

# %%
import gen_datasets

# %%
gen_datasets.tract_level_raw()
# Out:
# ['age', 'education', 'employment', 'ethnicity', 'rent_to_income', 'tenure', 'vacancy', 'years', 'income', 'poverty', 'insurance', 'nativity', 'origin', 'means', 'travel']
# type a variable to look up from above :  travel
#              FIPS                 Tract            County      State  \
# 0     21005950201  Census Tract 9502.01   Anderson County   Kentucky
# 1     21005950202  Census Tract 9502.02   Anderson County   Kentucky
# 2     21013961100  Census Tract 9611      Bell County       Kentucky
# 3     21015070311  Census Tract 703.11    Boone County      Kentucky
# 4     21015070312  Census Tract 703.12    Boone County      Kentucky
# ...           ...                  ...             ...           ...
# 1110  21095970200  Census Tract 9702      Harlan County     Kentucky
# 1111  21095970900  Census Tract 9709      Harlan County     Kentucky
# 1112  21095970100  Census Tract 9701      Harlan County     Kentucky
# 1113  21095970700  Census Tract 9707      Harlan County     Kentucky
# 1114  21095970800  Census Tract 9708      Harlan County     Kentucky
#
#       60 to 89 minutes  90 or more minutes  40 to 44 minutes  \
# 0     193.0             16.0                261.0
# 1     117.0             31.0                89.0
# 2     0.0               19.0                15.0
# 3     39.0              25.0                31.0
# 4     47.0              0.0                 44.0
# ...    ...              ...                  ...
# 1110  45.0              14.0                17.0
# 1111  51.0              32.0                0.0
# 1112  10.0              11.0                10.0
# 1113  36.0              37.0                43.0
# 1114  16.0              0.0                 2.0
#
#       45 to 59 minutes  Less than 5 minutes  5 to 9 minutes  10 to 14 minutes  \
# 0     100.0             44.0                 362.0           104.0
# 1     146.0             76.0                 255.0           126.0
# 2     51.0              97.0                 40.0            45.0
# 3     86.0              79.0                 90.0            276.0
# 4     34.0              114.0                229.0           380.0
# ...    ...                ...                  ...             ...
# 1110  17.0              155.0                125.0           127.0
# 1111  41.0              33.0                 299.0           257.0
# 1112  44.0              66.0                 80.0            76.0
# 1113  20.0              44.0                 204.0           328.0
# 1114  23.0              82.0                 58.0            59.0
#
#       15 to 19 minutes  20 to 24 minutes  25 to 29 minutes  35 to 39 minutes  \
# 0     321.0             244.0             214.0             49.0
# 1     124.0             213.0             99.0              106.0
# 2     126.0             91.0              27.0              38.0
# 3     226.0             296.0             54.0              10.0
# 4     221.0             221.0             35.0              83.0
# ...     ...               ...              ...               ...
# 1110  127.0             30.0              9.0               49.0
# 1111  81.0              7.0               3.0               0.0
# 1112  44.0              15.0              7.0               14.0
# 1113  170.0             100.0             2.0               18.0
# 1114  42.0              7.0               16.0              0.0
#
#       30 to 34 minutes   total
# 0     320.0             2228.0
# 1     251.0             1633.0
# 2     150.0             699.0
# 3     63.0              1275.0
# 4     146.0             1554.0
# ...     ...                ...
# 1110  110.0             825.0
# 1111  11.0              815.0
# 1112  15.0              392.0
# 1113  30.0              1032.0
# 1114  14.0              319.0
#
# [1115 rows x 17 columns]

# %%
gen_datasets.tract_level_perc()
# Out:
# ['age', 'education', 'employment', 'ethnicity', 'rent_to_income', 'tenure', 'vacancy', 'years', 'income', 'poverty', 'insurance', 'nativity', 'origin', 'means', 'travel']
# type a variable to look up from above :  employment
#              FIPS                 Tract            County      State  \
# 0     21005950201  Census Tract 9502.01   Anderson County   Kentucky
# 1     21005950202  Census Tract 9502.02   Anderson County   Kentucky
# 2     21013961100  Census Tract 9611      Bell County       Kentucky
# 3     21015070311  Census Tract 703.11    Boone County      Kentucky
# 4     21015070312  Census Tract 703.12    Boone County      Kentucky
# ...           ...                  ...             ...           ...
# 1110  21095970200  Census Tract 9702      Harlan County     Kentucky
# 1111  21095970900  Census Tract 9709      Harlan County     Kentucky
# 1112  21095970100  Census Tract 9701      Harlan County     Kentucky
# 1113  21095970700  Census Tract 9707      Harlan County     Kentucky
# 1114  21095970800  Census Tract 9708      Harlan County     Kentucky
#
#       employed  unemployed
# 0     0.846490  0.153510
# 1     0.932546  0.067454
# 2     0.880893  0.119107
# 3     0.952274  0.047726
# 4     0.967723  0.032277
# ...        ...       ...
# 1110  0.840509  0.159491
# 1111  0.791096  0.208904
# 1112  0.982927  0.017073
# 1113  0.908155  0.091845
# 1114  0.947222  0.052778
#
# [1115 rows x 6 columns]

# %%
gen_datasets.county_level_raw()
# Out:
# ['age', 'education', 'employment', 'ethnicity', 'rent_to_income', 'tenure', 'vacancy', 'years', 'income', 'poverty', 'insurance', 'nativity', 'origin', 'means', 'travel']
# type a variable to look up from above :  tenure
#          State            County  Renter occupied  Owner occupied    total
# 0     Kentucky   Adair County     3876.0           13955.0         17831.0
# 1     Kentucky   Allen County     5258.0           15464.0         20722.0
# 2     Kentucky   Anderson County  5026.0           17280.0         22306.0
# 3     Kentucky   Ballard County   1413.0           6500.0          7913.0
# 4     Kentucky   Barren County    14668.0          28465.0         43133.0
# ..         ...             ...        ...              ...             ...
# 115   Kentucky   Wayne County     5815.0           14414.0         20229.0
# 116   Kentucky   Webster County   3317.0           9342.0          12659.0
# 117   Kentucky   Whitley County   10487.0          23754.0         34241.0
# 118   Kentucky   Wolfe County     2139.0           4926.0          7065.0
# 119   Kentucky   Woodford County  7593.0           18360.0         25953.0
#
# [120 rows x 5 columns]

# %%
gen_datasets.county_level_perc()
# Out:
# ['age', 'education', 'employment', 'ethnicity', 'rent_to_income', 'tenure', 'vacancy', 'years', 'income', 'poverty', 'insurance', 'nativity', 'origin', 'means', 'travel']
# type a variable to look up from above :  origin
#          State            County    Native  Foreign-Born
# 0     Kentucky   Adair County     0.983821  0.016179
# 1     Kentucky   Allen County     0.981474  0.018526
# 2     Kentucky   Anderson County  0.988933  0.011067
# 3     Kentucky   Ballard County   0.975224  0.024776
# 4     Kentucky   Barren County    0.980608  0.019392
# ..         ...             ...         ...       ...
# 115   Kentucky   Wayne County     0.977757  0.022243
# 116   Kentucky   Webster County   0.962810  0.037190
# 117   Kentucky   Whitley County   0.990562  0.009438
# 118   Kentucky   Wolfe County     0.998057  0.001943
# 119   Kentucky   Woodford County  0.954176  0.045824
#
# [120 rows x 4 columns]
