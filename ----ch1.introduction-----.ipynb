# %% [markdown]
# # 1. Introduction to ACS module

# %% [markdown]
# Before you begin, make sure yuo have the private key for the census data API.

# %%
# import sys
# import os
# Save the acs.py file in the same directory where this Rmd or ipynb file is being run.
# The following lines will add the current directory into the path
# so that it can search the py file in the directory when we try to import
# wd = os.getcwd()
# sys.path.append(wd)
import numpy as np
import pandas as pd
# acs will also import pandas, numpy, re, and requests modules
import MarkeyDataTools as mdt

# this reload function is just to reload the MarkeyDataTools module as I periodically edit and test the module.
# from importlib import reload

# %% [markdown]
# ## Introduction

# %% [markdown]
# As a test, I am creating a module that call up a dataset; and as an example I will show you how the functions in the acs.py can work out to execute the same tasks that were done in `acs_computer_broadband` in the Data/ACS folder.

# %% [markdown]
# There were five tables imported separately, but using acs, you can import the variables in one table.
# To do so, you need to set values for the following variables:
# * year
# * tablename (in a list)
#    - For example, if you want to lookup "B28005"(all_ind), "B28009A"(white), "B28009H"(white_nh), "B28009B"(black), "B28009I"(hisp), set the value for source as \["B28005", "B28009A", "B28009H", "B28009B", "B28009I" \]
# * source (the subgroup of acs datagroup)
#    - In this example, it will be acs1 as ``acs1`` is the annual data.
#    - Many counties are missing in the acs1 as this is annual; you can find others in the ``acs5``, which is conducted every 5 years.
# * state: the default value is 'KY', so you don't need to worry about it.

# %%
year = 2019
table =  ["B28005", "B28009A", "B28009H", "B28009B", "B28009I" ]
source = 'acs5'

# %% [markdown]
# ## Part I. importing the module and calling the acs class

# %% [markdown]
# Above, we alreay imported the MarkeyDataTool module by executing `import MarkeyDataTool as mdt`. Now, let's call the `acs` class
# To call the `acs` class, you need year, table and source at the very least.
# You can also set the region arguement, whose default level is "**county**".
# **Please note that when you first run the acs class, it will ask for your private key**

# %%
acs = mdt.acs(year = year, table = table, source = 'acs5')
# Out:
# insert your private key for the census data : ba1c94e9a1b43440cf3ef2bf0b7803ddc39bcf2d

# %% [markdown]
# As another example, let's call the acs class with the region argument **"tract"**

# %%
acs_tract = mdt.acs(year = year, table = table, source = 'acs5', region = 'tract')
# Out:
# insert your private key for the census data : ba1c94e9a1b43440cf3ef2bf0b7803ddc39bcf2d

# %% [markdown]
# When you just do this, the most important attribute you might want to take a look at is the variable table.
# The name of the attribute is `variable_table`. This contains every variables name in the entire acs5 data.
# Obviously, the table names are contained in the variable table, but they have extensions such as 001_E, 002_E, etc.

# %%
acs.variable_table.head()
# Out:
#            name  \
# 0  for
# 1  in
# 2  ucgid
# 3  B24022_060E
# 4  B19001B_014E
#
#                                                                                                label  \
# 0  Census API FIPS 'for' clause
# 1  Census API FIPS 'in' clause
# 2  Uniform Census Geography Identifier clause
# 3  Estimate!!Total:!!Female:!!Service occupations:!!Food preparation and serving related occupations
# 4  Estimate!!Total:!!$100,000 to $124,999
#
#                                                                                                                                                                          concept
# 0  Census API Geography Specification
# 1  Census API Geography Specification
# 2  Census API Geography Specification
# 3  SEX BY OCCUPATION AND MEDIAN EARNINGS IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) FOR THE FULL-TIME, YEAR-ROUND CIVILIAN EMPLOYED POPULATION 16 YEARS AND OVER
# 4  HOUSEHOLD INCOME IN THE PAST 12 MONTHS (IN 2019 INFLATION-ADJUSTED DOLLARS) (BLACK OR AFRICAN AMERICAN ALONE HOUSEHOLDER)

# %% [markdown]
# You don't need to check `acs_tract.variable_table` because you will get the same table as long as having the same value for the **source** argument

# %% [markdown]
# ### Part II. Pulling the acs date

# %% [markdown]
# Using the attribute function, **`gen_dataframe()`**, you will get the data you wanted.
# This will be stored in the object `acs`, so you can use other functions to tidy and wrangle data for your needs.

# %%
acs.gen_dataframe().head()
# Out:
#     FIPS           County      State B28005_012E B28005_011E B28005_010E  \
# 0  21079  Garrard County    Kentucky  724         8931        149
# 1  21037  Campbell County   Kentucky  4114        49138       823
# 2  21063  Elliott County    Kentucky  130         2734        0
# 3  21123  Larue County      Kentucky  1225        6658        13
# 4  21167  Mercer County     Kentucky  998         10650       0
#
#   B28005_016E B28005_015E B28005_014E B28005_013E  ... B28009B_005E  \
# 0  16          2191        3021        577         ...  87
# 1  123         10573       13480       2137        ...  653
# 2  0           730         1330        396         ...  0
# 3  4           1623        2309        538         ...  0
# 4  13          2680        3864        1154        ...  51
#
#   B28009B_001E B28009B_002E B28009B_006E B28009I_002E B28009I_001E  \
# 0  321          255          66           222          387
# 1  2416         2243         173          1776         1866
# 2  0            0            0            6            23
# 3  478          350          128          351          449
# 4  905          583          322          636          636
#
#   B28009I_004E B28009I_003E B28009I_006E B28009I_005E
# 0  118          0            165          104
# 1  1468         0            90           308
# 2  6            0            17           0
# 3  74           0            98           277
# 4  619          0            0            17
#
# [5 rows x 46 columns]

# %% [markdown]
# As you see, you have the county names and their FIPS numbers in the first columns.
# Now, let's see how it looks like when the geographical level is at **'tract'**

# %%
acs_tract.gen_dataframe().head()
# Out:
#           FIPS                 Tract            County      State B28005_012E  \
# 0  21005950201  Census Tract 9502.01   Anderson County   Kentucky  459
# 1  21005950202  Census Tract 9502.02   Anderson County   Kentucky  187
# 2  21013961100  Census Tract 9611      Bell County       Kentucky  83
# 3  21015070311  Census Tract 703.11    Boone County      Kentucky  17
# 4  21015070312  Census Tract 703.12    Boone County      Kentucky  118
#
#   B28005_011E B28005_010E B28005_016E B28005_015E B28005_014E  ...  \
# 0  2583        0           0           584         896         ...
# 1  2052        0           15          379         572         ...
# 2  1430        0           0           212         446         ...
# 3  1464        7           15          323         452         ...
# 4  1733        0           16          296         598         ...
#
#   B28009B_005E B28009B_001E B28009B_002E B28009B_006E B28009I_002E  \
# 0  0            356          312          44           0
# 1  0            0            0            0            149
# 2  0            0            0            0            0
# 3  0            165          165          0            35
# 4  187          240          240          0            92
#
#   B28009I_001E B28009I_004E B28009I_003E B28009I_006E B28009I_005E
# 0  0            0            0            0            0
# 1  149          80           0            0            69
# 2  0            0            0            0            0
# 3  35           35           0            0            0
# 4  92           92           0            0            0
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Part III. Searching the tables and variables

# %% [markdown]
# To search a varialbe by keyword, you can use `search` attribute. If you have already used the function `gen_dataframe`, you do not need additional arguments. If you did not, you would need to give an integer for the year value.
# Also, if you want to save the search result as a file, then the argument for `savefile`, whose default value is *False*, should now be *`True`* and you should give a `filename`. If you forgot the filename, don't worry, it will ask you once again. Please **note** that the file format should be **`csv`**. As a test, please type in **`'test.csv'`**.

# %%
acs.search('poverty,health')
# acs.search('poverty,heath', savefile = True)
# Out:
#      index     name  \
# 0    0      B17015
# 1    2      B17016
# 2    4      B17017
# 3    6      B17018
# 4    11     B17012
# ..   ..        ...
# 105  1058   B22003
# 106  1066   B17020H
# 107  1067   B17020I
# 108  1069   B17020F
# 109  1070   B17020G
#
#                                                                                                                                                            description  \
# 0    POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY SOCIAL SECURITY INCOME BY SUPPLEMENTAL SECURITY INCOME (SSI) AND CASH PUBLIC ASSISTANCE INCOME
# 1    POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY FAMILY TYPE BY WORK EXPERIENCE OF HOUSEHOLDER AND SPOUSE
# 2    POVERTY STATUS IN THE PAST 12 MONTHS BY HOUSEHOLD TYPE BY AGE OF HOUSEHOLDER
# 3    POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY EDUCATIONAL ATTAINMENT OF HOUSEHOLDER
# 4    POVERTY STATUS IN THE PAST 12 MONTHS OF FAMILIES BY HOUSEHOLD TYPE BY NUMBER OF RELATED CHILDREN UNDER 18 YEARS
# ..                                                                                                               ...
# 105  RECEIPT OF FOOD STAMPS/SNAP IN THE PAST 12 MONTHS BY POVERTY STATUS IN THE PAST 12 MONTHS FOR HOUSEHOLDS
# 106  POVERTY STATUS IN THE PAST 12 MONTHS BY AGE (WHITE ALONE, NOT HISPANIC OR LATINO)
# 107  POVERTY STATUS IN THE PAST 12 MONTHS BY AGE (HISPANIC OR LATINO)
# 108  POVERTY STATUS IN THE PAST 12 MONTHS BY AGE (SOME OTHER RACE ALONE)
# 109  POVERTY STATUS IN THE PAST 12 MONTHS BY AGE (TWO OR MORE RACES)
#
#     source
# 0    acs5
# 1    acs5
# 2    acs5
# 3    acs5
# 4    acs5
# ..    ...
# 105  acs5
# 106  acs5
# 107  acs5
# 108  acs5
# 109  acs5
#
# [110 rows x 4 columns]

# %% [markdown]
# In the example above, comma (`,`) indicates **OR** operator. Therefore, you are searching the cases where description contains words proverty or health. I might improve the serach engine by including various seach opearators like **AND**, but for now, **OR** is the only option. However, if you know `regex`, you can also use the `search` function with the regex. Below is the example.

# %%
import re
pattern = re.compile('(?=health insurance)(?=.*sex)(?=.*age)', flags = re.I)
acs.search(pattern)
# Out:
#    index    name  \
# 0  106    B27022
# 1  335    B27001
#
#                                                                                    description  \
# 0  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 1  HEALTH INSURANCE COVERAGE STATUS BY SEX BY AGE
#
#   source
# 0  acs5
# 1  acs5

# %% [markdown]
# In this example, I searched cases where description contains words `health insurance`, `sex`, and `age`. **`flags = re.I`** lets this search engine to ignore the case of the letters. For more information on regex and its operations, please visit [regex tutorial](https://www.w3schools.com/python/python_regex.asp)

# %% [markdown]
# Now, let's say you think you want to explore more about the group `'B27022'`. You can use the attribute function **`gen_group_varible_desc`** with the `group` argument (it is an abbreviation of generate group's variable description). The `group` argument can have one group in a string format or it can also be a list or numpy array that contains a number of it. Let's see what we get for `'B27022'`

# %%
acs.gen_group_variable_desc('B27022')
# Out:
#              name  \
# 9906  B27022_001E
# 9891  B27022_002E
# 9895  B27022_003E
# 9827  B27022_004E
# 9828  B27022_005E
# 9824  B27022_006E
# 9825  B27022_007E
# 9822  B27022_008E
# 9823  B27022_009E
# 9835  B27022_010E
# 9836  B27022_011E
# 9833  B27022_012E
# 9834  B27022_013E
# 9829  B27022_014E
# 9830  B27022_015E
#
#                                                                                    label  \
# 9906  Estimate!!Total:
# 9891  Estimate!!Total:!!Male:
# 9895  Estimate!!Total:!!Male:!!Enrolled in school:
# 9827  Estimate!!Total:!!Male:!!Enrolled in school:!!With health insurance coverage
# 9828  Estimate!!Total:!!Male:!!Enrolled in school:!!No health insurance coverage
# 9824  Estimate!!Total:!!Male:!!Not enrolled in school:
# 9825  Estimate!!Total:!!Male:!!Not enrolled in school:!!With health insurance coverage
# 9822  Estimate!!Total:!!Male:!!Not enrolled in school:!!No health insurance coverage
# 9823  Estimate!!Total:!!Female:
# 9835  Estimate!!Total:!!Female:!!Enrolled in school:
# 9836  Estimate!!Total:!!Female:!!Enrolled in school:!!With health insurance coverage
# 9833  Estimate!!Total:!!Female:!!Enrolled in school:!!No health insurance coverage
# 9834  Estimate!!Total:!!Female:!!Not enrolled in school:
# 9829  Estimate!!Total:!!Female:!!Not enrolled in school:!!With health insurance coverage
# 9830  Estimate!!Total:!!Female:!!Not enrolled in school:!!No health insurance coverage
#
#                                                                                           concept
# 9906  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9891  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9895  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9827  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9828  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9824  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9825  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9822  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9823  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9835  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9836  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9833  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9834  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9829  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25
# 9830  HEALTH INSURANCE COVERAGE STATUS BY SEX BY ENROLLMENT STATUS FOR YOUNG ADULTS AGED 19 TO 25

# %% [markdown]
# What if I want to see the description of the variables in the groups `"B28005" and "B28009A"` together? The group argument would be \['B28005', 'B28009A' \]

# %%
acs.gen_group_variable_desc(['B28005','B28009A'])
# Out:
#               name  \
# 2468  B28005_001E
# 2461  B28005_002E
# 2457  B28005_003E
# 2452  B28005_004E
# 2486  B28005_005E
# 2483  B28005_006E
# 2477  B28005_007E
# 2479  B28005_008E
# 2475  B28005_009E
# 2298  B28005_010E
# 2294  B28005_011E
# 2289  B28005_012E
# 2374  B28005_013E
# 2368  B28005_014E
# 2366  B28005_015E
# 2364  B28005_016E
# 2378  B28005_017E
# 2376  B28005_018E
# 2377  B28005_019E
# 6000  B28009A_001E
# 6177  B28009A_002E
# 6181  B28009A_003E
# 6190  B28009A_004E
# 6186  B28009A_005E
# 6191  B28009A_006E
#
#                                                                                                 label  \
# 2468  Estimate!!Total:
# 2461  Estimate!!Total:!!Under 18 years:
# 2457  Estimate!!Total:!!Under 18 years:!!Has a computer:
# 2452  Estimate!!Total:!!Under 18 years:!!Has a computer:!!With dial-up Internet subscription alone
# 2486  Estimate!!Total:!!Under 18 years:!!Has a computer:!!With a broadband Internet subscription
# 2483  Estimate!!Total:!!Under 18 years:!!Has a computer:!!Without an Internet subscription
# 2477  Estimate!!Total:!!Under 18 years:!!No computer
# 2479  Estimate!!Total:!!18 to 64 years:
# 2475  Estimate!!Total:!!18 to 64 years:!!Has a computer:
# 2298  Estimate!!Total:!!18 to 64 years:!!Has a computer:!!With dial-up Internet subscription alone
# 2294  Estimate!!Total:!!18 to 64 years:!!Has a computer:!!With a broadband Internet subscription
# 2289  Estimate!!Total:!!18 to 64 years:!!Has a computer:!!Without an Internet subscription
# 2374  Estimate!!Total:!!18 to 64 years:!!No computer
# 2368  Estimate!!Total:!!65 years and over:
# 2366  Estimate!!Total:!!65 years and over:!!Has a computer:
# 2364  Estimate!!Total:!!65 years and over:!!Has a computer:!!With dial-up Internet subscription alone
# 2378  Estimate!!Total:!!65 years and over:!!Has a computer:!!With a broadband Internet subscription
# 2376  Estimate!!Total:!!65 years and over:!!Has a computer:!!Without an Internet subscription
# 2377  Estimate!!Total:!!65 years and over:!!No computer
# 6000  Estimate!!Total:
# 6177  Estimate!!Total:!!Has a computer:
# 6181  Estimate!!Total:!!Has a computer:!!With dial-up Internet subscription alone
# 6190  Estimate!!Total:!!Has a computer:!!With a broadband Internet subscription
# 6186  Estimate!!Total:!!Has a computer:!!Without an Internet subscription
# 6191  Estimate!!Total:!!No Computer
#
#                                                                                   concept
# 2468  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2461  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2457  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2452  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2486  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2483  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2477  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2479  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2475  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2298  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2294  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2289  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2374  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2368  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2366  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2364  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2378  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2376  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2377  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 6000  PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (WHITE ALONE)
# 6177  PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (WHITE ALONE)
# 6181  PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (WHITE ALONE)
# 6190  PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (WHITE ALONE)
# 6186  PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (WHITE ALONE)
# 6191  PRESENCE OF A COMPUTER AND TYPE OF INTERNET SUBSCRIPTION IN HOUSEHOLD (WHITE ALONE)

# %% [markdown]
# Lastly, the latest search result is stored as attribute `'group_variable_desc'`

# %%
acs.group_variable_desc.head()
# Out:
#              name  \
# 2468  B28005_001E
# 2461  B28005_002E
# 2457  B28005_003E
# 2452  B28005_004E
# 2486  B28005_005E
#
#                                                                                              label  \
# 2468  Estimate!!Total:
# 2461  Estimate!!Total:!!Under 18 years:
# 2457  Estimate!!Total:!!Under 18 years:!!Has a computer:
# 2452  Estimate!!Total:!!Under 18 years:!!Has a computer:!!With dial-up Internet subscription alone
# 2486  Estimate!!Total:!!Under 18 years:!!Has a computer:!!With a broadband Internet subscription
#
#                                                                             concept
# 2468  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2461  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2457  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2452  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD
# 2486  AGE BY PRESENCE OF A COMPUTER AND TYPES OF INTERNET SUBSCRIPTION IN HOUSEHOLD

# %% [markdown]
# ## Part IV. Renaming and aggregating variables

# %% [markdown]
# You might want to rename the group **`B28005`** with the name **`computer_internet`** as variables in the group indicate estimates of the population having a computer or an internet subscription by age group. In addition, since **`B28009A`** is technically the same group for the white population alone, so it would be appropriate to rename the group as **`computer_internet_white`**.
# To do so, you use the **`rename_group`** attribute function and the **`sub`** argument in the function requires a dictionary in the following format:
# * { 'new name1' : 'original group name1', 'new name2': 'original group name2'}
#
#
# Hence, in our example, the sub argument would be {'computer_internet' : 'B28005', 'computer_internet_white': 'B28009A'}. Obviously, you may not need to rename them as long as you are comfortable with the original group name. Don't worry about the case of the letters.

# %% [markdown]
# **If you want to permanently replace the group names, set the inplace argument, whose default value is *`False`*, as *`True`*.**

# %% [markdown]
# Because we have to discuss `aggregate` attribute function after this, we will not touch the inplace argment.

# %%
sub_dict = {'computer_internet' : 'B28005', 'computer_internet_white': 'b28009A'}

# %%
acs.rename_group(sub_dict)
# Out:
#       FIPS           County      State computer_internet_012E  \
# 0    21001  Adair County      Kentucky  1049
# 1    21003  Allen County      Kentucky  1815
# 2    21005  Anderson County   Kentucky  1645
# 3    21007  Ballard County    Kentucky  387
# 4    21009  Barren County     Kentucky  1664
# ..     ...            ...          ...   ...
# 115  21231  Wayne County      Kentucky  1159
# 116  21233  Webster County    Kentucky  970
# 117  21235  Whitley County    Kentucky  2072
# 118  21237  Wolfe County      Kentucky  249
# 119  21239  Woodford County   Kentucky  906
#
#     computer_internet_011E computer_internet_010E computer_internet_016E  \
# 0    8294                   114                    34
# 1    8991                   51                     42
# 2    11323                  4                      24
# 3    3871                   4                      0
# 4    22015                  60                     52
# ..     ...                  ..                     ..
# 115  8491                   0                      0
# 116  5665                   4                      13
# 117  14638                  0                      0
# 118  3220                   13                     0
# 119  13739                  33                     59
#
#     computer_internet_015E computer_internet_014E computer_internet_013E  ...  \
# 0    2387                   3487                   1236                   ...
# 1    2551                   3550                   1333                   ...
# 2    2475                   3376                   610                    ...
# 3    1176                   1610                   276                    ...
# 4    4990                   7038                   1920                   ...
# ..    ...                    ...                    ...                   ...
# 115  2300                   4041                   2262                   ...
# 116  1462                   2181                   825                    ...
# 117  3171                   5428                   3042                   ...
# 118  667                    1291                   655                    ...
# 119  3990                   4670                   750                    ...
#
#     B28009B_005E B28009B_001E B28009B_002E B28009B_006E B28009I_002E  \
# 0    0            455          234          221          264
# 1    105          187          148          39           369
# 2    12           623          548          75           378
# 3    26           313          232          81           97
# 4    135          1489         1008         481          1345
# ..   ...           ...          ...         ...           ...
# 115  0            357          148          209          258
# 116  0            415          344          71           471
# 117  7            99           99           0            428
# 118  0            0            0            0            23
# 119  208          1121         836          285          1584
#
#     B28009I_001E B28009I_004E B28009I_003E B28009I_006E B28009I_005E
# 0    316          261          0            52           3
# 1    452          312          0            83           57
# 2    403          309          0            25           69
# 3    109          95           0            12           2
# 4    1415         1258         0            70           87
# ..    ...          ...        ..            ..           ..
# 115  679          220          0            421          38
# 116  705          392          0            234          79
# 117  428          428          0            0            0
# 118  23           0            0            0            23
# 119  1748         1398         0            164          186
#
# [120 rows x 46 columns]

# %% [markdown]
# Let's check how the column name of the **`acs_data`** has transformed.

# %%
acs.rename_group(sub_dict).columns
# Out:
# Index(['FIPS', 'County', 'State', 'computer_internet_012E',
#        'computer_internet_011E', 'computer_internet_010E',
#        'computer_internet_016E', 'computer_internet_015E',
#        'computer_internet_014E', 'computer_internet_013E',
#        'computer_internet_018E', 'computer_internet_019E',
#        'computer_internet_017E', 'computer_internet_004E',
#        'computer_internet_003E', 'computer_internet_002E',
#        'computer_internet_001E', 'computer_internet_009E',
#        'computer_internet_007E', 'computer_internet_008E',
#        'computer_internet_006E', 'computer_internet_005E', 'B28009A_001E',
#        'B28009A_002E', 'B28009A_003E', 'B28009A_005E', 'B28009A_004E',
#        'B28009A_006E', 'B28009H_001E', 'B28009H_002E', 'B28009H_003E',
#        'B28009H_004E', 'B28009H_005E', 'B28009H_006E', 'B28009B_003E',
#        'B28009B_004E', 'B28009B_005E', 'B28009B_001E', 'B28009B_002E',
#        'B28009B_006E', 'B28009I_002E', 'B28009I_001E', 'B28009I_004E',
#        'B28009I_003E', 'B28009I_006E', 'B28009I_005E'],
#       dtype='object')

# %% [markdown]
# Now, let's discuss how to aggregate the columns.

# %% [markdown]
# As an example, we will sum up the values in the B28005_002E, B28005_003E, B28005_004E, B28005_005E, B28005_006E, and B28005_007E columns to create the 'Under 18 Years' column. Similar to `rename_group` attribute function, you need to provide a dictionary, for the `variables_dictionary` argument, that is constructed in the following way:
#
# `{'group name' : {'new variable name 1' : [ list of suffices ] , 'new variable name 2' : [list of suffices] } }`
#
# Then, in our example, it will be `{'B28005' : {'Under 18 Years' : [ '002E', '002E', ... , '007E' ] } }`

# %%
arg = {'B28005' : {'Under 18 Years' : ['002E', '003E','004E', '005E','006E','007E'] } }

# %%
acs.aggregate(arg)
# Out:
#       FIPS           County  Under 18 Years
# 0    21001  Adair County     10668.0
# 1    21003  Allen County     14419.0
# 2    21005  Anderson County  16006.0
# 3    21007  Ballard County   5250.0
# 4    21009  Barren County    30394.0
# ..     ...            ...        ...
# 115  21231  Wayne County     12206.0
# 116  21233  Webster County   8828.0
# 117  21235  Whitley County   25757.0
# 118  21237  Wolfe County     4753.0
# 119  21239  Woodford County  17354.0
#
# [120 rows x 3 columns]

# %% [markdown]
# If you set the inplace argument as `True`, then it will not only return the output dataframe, but also create the new columns in the `acs.acs_data` object. Another difference from the previous example is that it will contain all the pre-existing variables and the new variables will be placed at the end of the dataframe.

# %% [markdown]
# This function can handle more than one group and more than one new variables. Let's take a look at the following example:

# %%
arg = {'B28005' : {'Under 18 Years' : ['002E', '003E','004E', '005E','006E','007E'], '18 to 64 Years' : ['008E', '009E','010E', '011E','012E','013E'] } ,
      'B28009A' : {'Computer in the home (white)' : ['003E', '004E','005E'], 'No Computer in the home (white)' : ['006E'] } }

# %%
acs.aggregate(arg)
# Out:
#       FIPS           County  Under 18 Years  18 to 64 Years  \
# 0    21001  Adair County     10668.0         30566.0
# 1    21003  Allen County     14419.0         166499.0
# 2    21005  Anderson County  16006.0         9384.0
# 3    21007  Ballard County   5250.0          24764.0
# 4    21009  Barren County    30394.0         37252.0
# ..     ...            ...        ...             ...
# 115  21231  Wayne County     12206.0         63055.0
# 116  21233  Webster County   8828.0          19206.0
# 117  21235  Whitley County   25757.0         17788.0
# 118  21237  Wolfe County     4753.0          16381.0
# 119  21239  Woodford County  17354.0         15575.0
#
#      Computer in the home (white)  No Computer in the home (white)
# 0    15156.0                       1459.0
# 1    78912.0                       5115.0
# 2    4821.0                        1132.0
# 3    11728.0                       1197.0
# 4    17791.0                       2141.0
# ..       ...                          ...
# 115  30638.0                       2277.0
# 116  7607.0                        3034.0
# 117  8470.0                        1070.0
# 118  7284.0                        2482.0
# 119  7200.0                        801.0
#
# [120 rows x 6 columns]

# %% [markdown]
# Another way to do the same with the suffix indices is to use **`iaggregate`** attribute function. Everything is the same, but the list of suffices is not just a list of integers. In our example, it would be `{'B28005' : {'Under 18 Years' :  np.arange(2, 8) } }`

# %%
arg = {'B28005' : {'Under 18 Years' :  np.arange(2, 8) } }
acs.iaggregate(arg)
# Out:
#       FIPS           County  Under 18 Years_B28005
# 0    21001  Adair County     10668.0
# 1    21003  Allen County     14419.0
# 2    21005  Anderson County  16006.0
# 3    21007  Ballard County   5250.0
# 4    21009  Barren County    30394.0
# ..     ...            ...        ...
# 115  21231  Wayne County     12206.0
# 116  21233  Webster County   8828.0
# 117  21235  Whitley County   25757.0
# 118  21237  Wolfe County     4753.0
# 119  21239  Woodford County  17354.0
#
# [120 rows x 3 columns]

# %% [markdown]
# Similar to the previous example, you can do the following:

# %%
arg = {'B28005' : {'Under 18 Years' :np.arange(2, 8), '18 to 64 Years' : np.arange(8, 14) } ,
      'B28009A' : {'Computer in the home (white)' : np.arange(3, 6), 'No Computer in the home (white)' : [6] } }

# %%
acs.iaggregate(arg).iloc[:, 2:].to_numpy().reshape(-1)
# Out:
# array([1.066800e+04, 3.084300e+04, 1.464200e+04, 2.400000e+03,
#        1.441900e+04, 3.523700e+04, 1.726000e+04, 2.752000e+03,
#        1.600600e+04, 4.013600e+04, 1.980600e+04, 1.436000e+03,
#        5.250000e+03, 1.333800e+04, 6.700000e+03, 6.480000e+02,
#        3.039400e+04, 7.505700e+04, 3.569700e+04, 4.324000e+03,
#        9.222000e+03, 2.095800e+04, 1.019100e+04, 1.664000e+03,
#        1.667300e+04, 4.389300e+04, 2.031900e+04, 4.486000e+03,
#        1.033260e+05, 2.346990e+05, 1.142090e+05, 3.616000e+03,
#        1.347600e+04, 3.379800e+04, 1.625400e+04, 1.652000e+03,
#        2.997500e+04, 8.002400e+04, 4.020100e+04, 3.451000e+03,
#        1.759400e+04, 4.607400e+04, 2.183200e+04, 2.152000e+03,
#        5.828000e+03, 1.442900e+04, 6.973000e+03, 1.043000e+03,
#        7.559000e+03, 2.268000e+04, 1.012000e+04, 2.273000e+03,
#        1.352000e+04, 3.311600e+04, 1.614000e+04, 2.843000e+03,
#        5.277100e+04, 1.477800e+05, 7.197200e+04, 4.537000e+03,
#        8.375000e+03, 2.178700e+04, 1.048900e+04, 1.690000e+03,
#        8.280000e+03, 2.090900e+04, 1.051500e+04, 1.143000e+03,
#        2.083200e+04, 6.394000e+04, 3.005100e+04, 2.129000e+03,
#        5.837500e+04, 1.664990e+05, 7.891200e+04, 5.115000e+03,
#        3.260000e+03, 7.924000e+03, 4.178000e+03, 3.440000e+02,
#        8.160000e+03, 1.778800e+04, 8.470000e+03, 1.070000e+03,
#        1.754100e+04, 4.381100e+04, 2.071200e+04, 5.327000e+03,
#        1.016700e+04, 2.513500e+04, 1.219900e+04, 2.845000e+03,
#        5.649700e+04, 1.092140e+05, 4.140600e+04, 4.517000e+03,
#        2.414500e+04, 6.305500e+04, 3.063800e+04, 2.277000e+03,
#        1.262300e+04, 3.345700e+04, 1.544600e+04, 2.859000e+03,
#        6.323000e+03, 1.638100e+04, 7.284000e+03, 2.482000e+03,
#        5.838000e+03, 1.437100e+04, 7.117000e+03, 1.409000e+03,
#        4.325000e+03, 1.094600e+04, 5.278000e+03, 8.540000e+02,
#        7.256100e+04, 1.677640e+05, 8.113000e+04, 6.661000e+03,
#        6.714000e+03, 2.090200e+04, 1.003700e+04, 1.381000e+03,
#        4.007000e+03, 9.384000e+03, 4.821000e+03, 1.132000e+03,
#        9.150000e+03, 2.445400e+04, 1.197100e+04, 2.017000e+03,
#        1.994130e+05, 5.983760e+05, 2.225840e+05, 7.921000e+03,
#        1.009500e+04, 2.445500e+04, 1.176500e+04, 2.181000e+03,
#        2.328800e+04, 6.299500e+04, 3.110200e+04, 3.893000e+03,
#        3.094600e+04, 8.807100e+04, 3.769100e+04, 2.943000e+03,
#        3.906000e+03, 9.098000e+03, 3.527000e+03, 5.350000e+02,
#        6.351000e+03, 1.557500e+04, 7.200000e+03, 8.010000e+02,
#        1.157800e+04, 3.056600e+04, 1.515600e+04, 1.459000e+03,
#        1.962400e+04, 4.246900e+04, 2.097100e+04, 2.503000e+03,
#        2.659000e+04, 6.169300e+04, 2.949700e+04, 3.439000e+03,
#        1.853700e+04, 4.448400e+04, 2.201600e+04, 2.877000e+03,
#        6.896000e+03, 1.861600e+04, 8.955000e+03, 1.356000e+03,
#        2.269000e+04, 6.089200e+04, 3.157900e+04, 2.514000e+03,
#        6.465000e+03, 1.461900e+04, 7.534000e+03, 7.500000e+02,
#        7.915100e+04, 1.917080e+05, 7.864900e+04, 5.431000e+03,
#        1.791500e+04, 4.394300e+04, 2.097500e+04, 3.916000e+03,
#        1.251700e+04, 3.184000e+04, 1.503400e+04, 2.460000e+03,
#        1.330300e+04, 3.075900e+04, 1.399000e+04, 3.266000e+03,
#        3.093300e+04, 7.674800e+04, 3.553900e+04, 3.630000e+03,
#        1.113500e+04, 2.779500e+04, 1.353100e+04, 1.236000e+03,
#        2.564000e+03, 7.164000e+03, 3.092000e+03, 6.940000e+02,
#        3.034500e+04, 7.609500e+04, 3.520700e+04, 4.753000e+03,
#        8.707000e+03, 2.326100e+04, 1.116100e+04, 1.853000e+03,
#        5.059970e+05, 1.369032e+06, 5.053990e+05, 3.251200e+04,
#        3.850800e+04, 9.094700e+04, 4.403500e+04, 2.783000e+03,
#        1.506900e+04, 3.781900e+04, 1.888000e+04, 2.610000e+03,
#        1.182450e+05, 3.002820e+05, 1.402870e+05, 6.846000e+03,
#        8.925000e+03, 2.572000e+04, 1.205700e+04, 2.170000e+03,
#        2.056200e+04, 5.164000e+04, 2.327500e+04, 6.365000e+03,
#        9.393000e+03, 2.476400e+04, 1.172800e+04, 1.197000e+03,
#        4.050500e+04, 1.051050e+05, 5.040400e+04, 7.315000e+03,
#        1.097800e+04, 2.623600e+04, 1.272200e+04, 2.675000e+03,
#        4.124000e+03, 1.089000e+04, 4.924000e+03, 1.294000e+03,
#        6.582000e+03, 1.723700e+04, 8.164000e+03, 1.583000e+03,
#        1.425800e+04, 3.820800e+04, 1.873200e+04, 2.857000e+03,
#        8.881000e+03, 2.289300e+04, 1.115100e+04, 1.832000e+03,
#        1.650900e+04, 4.066800e+04, 1.914200e+04, 3.764000e+03,
#        5.713000e+03, 1.562600e+04, 7.923000e+03, 9.990000e+02,
#        1.816800e+04, 4.389600e+04, 2.028600e+04, 3.786000e+03,
#        3.353000e+03, 1.085600e+04, 5.655000e+03, 8.700000e+02,
#        4.285000e+04, 1.094360e+05, 5.022000e+04, 4.187000e+03,
#        1.140800e+04, 2.580000e+04, 1.209200e+04, 3.013000e+03,
#        6.545000e+03, 1.550800e+04, 8.100000e+03, 8.030000e+02,
#        5.645600e+04, 1.588960e+05, 7.300300e+04, 4.535000e+03,
#        8.389000e+03, 2.180500e+04, 1.043400e+04, 1.907000e+03,
#        1.382600e+04, 3.107500e+04, 1.455100e+04, 2.090000e+03,
#        1.906900e+04, 5.205100e+04, 2.738400e+04, 2.457000e+03,
#        6.838000e+03, 1.805800e+04, 8.617000e+03, 1.714000e+03,
#        1.117700e+04, 2.929100e+04, 1.314100e+04, 2.110000e+03,
#        1.932200e+04, 5.188400e+04, 2.398900e+04, 1.637000e+03,
#        3.974000e+03, 1.091800e+04, 5.314000e+03, 9.270000e+02,
#        1.418900e+04, 3.725200e+04, 1.779100e+04, 2.141000e+03,
#        6.760000e+03, 1.705700e+04, 8.303000e+03, 1.195000e+03,
#        6.911000e+03, 1.797400e+04, 8.474000e+03, 1.575000e+03,
#        1.964200e+04, 4.855000e+04, 2.364800e+04, 2.339000e+03,
#        7.117000e+03, 2.028400e+04, 9.252000e+03, 2.057000e+03,
#        1.865400e+04, 5.288300e+04, 2.431100e+04, 3.717000e+03,
#        3.239400e+04, 8.138200e+04, 3.850600e+04, 2.746000e+03,
#        4.794000e+03, 1.209800e+04, 5.402000e+03, 1.375000e+03,
#        1.739700e+04, 3.996800e+04, 2.006300e+04, 2.892000e+03,
#        5.054100e+04, 1.117730e+05, 5.624800e+04, 1.340000e+03,
#        7.226000e+03, 1.852600e+04, 9.030000e+03, 1.543000e+03,
#        2.665000e+03, 7.588000e+03, 3.254000e+03, 8.170000e+02,
#        1.012300e+04, 2.576300e+04, 1.285700e+04, 1.062000e+03,
#        1.745000e+04, 4.626500e+04, 2.156600e+04, 3.402000e+03,
#        3.666300e+04, 1.039990e+05, 5.104600e+04, 5.838000e+03,
#        8.540000e+03, 2.068400e+04, 9.678000e+03, 1.995000e+03,
#        4.212600e+04, 1.092660e+05, 5.400100e+04, 7.160000e+03,
#        1.482000e+03, 3.301000e+03, 1.658000e+03, 3.670000e+02,
#        1.093500e+04, 2.865000e+04, 1.364200e+04, 2.541000e+03,
#        1.353100e+04, 4.039600e+04, 1.896700e+04, 1.979000e+03,
#        1.156400e+04, 2.885100e+04, 1.377700e+04, 2.814000e+03,
#        4.144400e+04, 9.831200e+04, 4.510900e+04, 1.809000e+03,
#        3.268300e+04, 8.227500e+04, 3.814700e+04, 1.892000e+03,
#        1.311100e+04, 3.038000e+04, 1.357900e+04, 1.726000e+03,
#        1.287900e+04, 3.512100e+04, 1.701700e+04, 8.260000e+02,
#        1.720800e+04, 4.186600e+04, 2.006700e+04, 2.486000e+03,
#        8.827000e+03, 1.920600e+04, 7.607000e+03, 3.034000e+03,
#        9.087000e+03, 2.336100e+04, 1.119100e+04, 1.824000e+03,
#        5.512000e+03, 1.518400e+04, 7.186000e+03, 1.008000e+03,
#        8.104000e+03, 2.349400e+04, 1.047700e+04, 1.131000e+03,
#        8.617600e+04, 2.262370e+05, 9.301000e+04, 5.939000e+03,
#        8.256000e+03, 1.986100e+04, 9.225000e+03, 1.207000e+03,
#        1.220600e+04, 3.347400e+04, 1.500600e+04, 4.116000e+03,
#        8.828000e+03, 2.156700e+04, 9.869000e+03, 1.678000e+03,
#        2.575700e+04, 5.621400e+04, 2.679800e+04, 6.652000e+03,
#        4.753000e+03, 1.175600e+04, 5.560000e+03, 1.402000e+03,
#        1.735400e+04, 4.553400e+04, 2.255300e+04, 1.304000e+03])

# %% [markdown]
# #### 4-1. Slicing Tables given group names and variable index number

# %% [markdown]
# Before we move on to talk about creating a variable with a subset of variables, it is essential to discuss how to slice the acs data with given group name and their variable index numbers. As an example, you are interested in the values of 'B28005_001E', 'B28005_003E', 'B28005_005E', 'B28009A_001E', 'B28009A_001E',and 'B28009A_001E'. Simply, you can find the values by running the following line:
# `acs.loc[:, ['B28005_001E', 'B28005_003E', 'B28005_005E', 'B28009A_001E', 'B28009A_001E', 'B28009A_001E'] ]`
#
# However, there is another function you might need to consider: `group_isel`. It takes the list of groupname and the variable index (or suffix) numbers.
# In our case, the group names are 'B28005' and 'B28009A'. The index numbers are 1, 3, and 5 for both. Let's see what you will get when you run the following code:
#
#
# `acs.group_isel( ['B28005','B28009A'], [[1,3,5], [1,3,5]] )`

# %%
acs.group_isel( ['B28005','B28009A'], 
                     [[1,3,5], [1,3,5]])
# Out:
#       FIPS           County B28005_001E B28005_003E B28005_005E B28009A_001E  \
# 0    21001  Adair County     17831       3366        2962        17042
# 1    21003  Allen County     20722       4455        3956        20012
# 2    21005  Anderson County  22306       5310        4667        21242
# 3    21007  Ballard County   7913        1720        1561        7348
# 4    21009  Barren County    43133       9522        8938        40021
# ..     ...            ...      ...        ...         ...          ...
# 115  21231  Wayne County     20229       3654        3287        19122
# 116  21233  Webster County   12659       2800        2348        11547
# 117  21235  Whitley County   34241       7635        7040        33450
# 118  21237  Wolfe County     7065        1479        1460        6962
# 119  21239  Woodford County  25953       5644        5189        23857
#
#     B28009A_003E B28009A_005E
# 0    179          1700
# 1    107          2590
# 2    28           2558
# 3    4            690
# 4    120          2382
# ..   ...           ...
# 115  0            1775
# 116  17           1506
# 117  0            2917
# 118  13           432
# 119  92           1489
#
# [120 rows x 8 columns]

# %% [markdown]
# It has another argument, `stack`, and its default value is `False`. When you set this `True`, what happens is they stack the dataframe in a way that the `Variable` column contain the column names in the original data frame and `Values` column contain the corresponding values. Let's see what you actually get.

# %%
acs.group_isel( ['B28005','B28009A'], 
                     [[1,3,5], [1,3,5]], stack = True)
# Out:
#       FIPS           County      Variable Values
# 0    21001  Adair County     B28005_001E   17831
# 1    21001  Adair County     B28005_003E   3366
# 2    21001  Adair County     B28005_005E   2962
# 3    21001  Adair County     B28009A_001E  17042
# 4    21001  Adair County     B28009A_003E  179
# ..     ...           ...              ...  ...
# 715  21239  Woodford County  B28005_003E   5644
# 716  21239  Woodford County  B28005_005E   5189
# 717  21239  Woodford County  B28009A_001E  23857
# 718  21239  Woodford County  B28009A_003E  92
# 719  21239  Woodford County  B28009A_005E  1489
#
# [720 rows x 4 columns]

# %% [markdown]
# #### 4-2. Subgrouping and aggregate by the subgroups (`acs_computer_broadband` example)

# %% [markdown]
# This is basically an extension of the **`isel`** with the stack argument **`True`**. Let's see how it was done in R below.

# %% [markdown]
# ![image.png](attachment:3b5f896d-6cd9-4ea5-9098-3c931b391738.png)

# %% [markdown]
# And below is the result of the transformation.

# %% [markdown]
# ![image.png](attachment:ef0735d9-5c79-445f-9b2f-ec6770ac49bf.png)

# %% [markdown]
# In short, the lines executed created the three variables, **`age`, `comp`, and `status`** based on the subgrouping.

# %% [markdown]
# To do the same within the acs module, we can utilize the **`gen_subgroups`** attribute function. This takes two main arguments with one optional argument. The main arguments are **`new_variables`** and **`groups`**. The datatype for an input for new_variables is a dictionary with the keys equal to the new variable names and with the values of another dictionary, which contains values of the new variable and the "suffix numbers" that defines this values. Then, the input for the **`new_variables`** in our case will be:

# %%
arg1 = {'age': {'Under 18 Years': np.arange(2, 8)    , '18 to 64 Years':  np.arange(8, 14)   , '65 Years and Over':  np.arange(14, 20)   }   , 
        'comp':  {'Computer in the Home': np.concatenate([np.arange(4, 7), np.arange(10, 13), np.arange(16, 19)]), 'No Computer in the Home': np.array([7,13,19])     }   ,
        'status':  {'Broadband Access': np.array([5, 11, 17])       , 'No Broadband Access': np.array([4,6,7,10,12, 13, 16, 18,19])   } }
acs.gen_subgroups(arg1, groups =['B28005'])
# Out:
#        FIPS           County      State                age  \
# 0     21001  Adair County      Kentucky  Under 18 Years
# 1     21001  Adair County      Kentucky  Under 18 Years
# 2     21001  Adair County      Kentucky  Under 18 Years
# 3     21001  Adair County      Kentucky  18 to 64 Years
# 4     21001  Adair County      Kentucky  18 to 64 Years
# ...     ...           ...           ...             ...
# 1075  21239  Woodford County   Kentucky  18 to 64 Years
# 1076  21239  Woodford County   Kentucky  18 to 64 Years
# 1077  21239  Woodford County   Kentucky  65 Years and Over
# 1078  21239  Woodford County   Kentucky  65 Years and Over
# 1079  21239  Woodford County   Kentucky  65 Years and Over
#
#                          comp               status  B28005
# 0     Computer in the Home     Broadband Access     2962.0
# 1     Computer in the Home     No Broadband Access  404.0
# 2     No Computer in the Home  No Broadband Access  285.0
# 3     Computer in the Home     Broadband Access     8294.0
# 4     Computer in the Home     No Broadband Access  1163.0
# ...                    ...                     ...     ...
# 1075  Computer in the Home     No Broadband Access  939.0
# 1076  No Computer in the Home  No Broadband Access  750.0
# 1077  Computer in the Home     Broadband Access     3561.0
# 1078  Computer in the Home     No Broadband Access  429.0
# 1079  No Computer in the Home  No Broadband Access  680.0
#
# [1080 rows x 7 columns]

# %% [markdown]
# Now, let's do another example. Since other groups 'B28009A', 'B28009B' do not contain information about age, we only can create two new variables; **`comp`** and **`status`**. Since the suffix numbers are not matching between B28005 and the other, we should use gen_subgroups twice and **merge** the two tables by the **`comp`** and **`status`**. Below is the R code for B28009A

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
arg1 = {'comp':  {'Computer in the Home': np.arange(3, 6), 'No Computer in the Home': np.array([6])},
        'status':  {'Broadband Access': np.array([4]) , 'No Broadband Access': np.array([3,5,6])}}
table1 = acs.gen_subgroups(arg1, ['B28009A','B28009B','B28009H','B28009I'])
table1
# Out:
#       FIPS           County      State                     comp  \
# 0    21001  Adair County      Kentucky  Computer in the Home
# 1    21001  Adair County      Kentucky  Computer in the Home
# 2    21001  Adair County      Kentucky  No Computer in the Home
# 3    21003  Allen County      Kentucky  Computer in the Home
# 4    21003  Allen County      Kentucky  Computer in the Home
# ..     ...           ...           ...                   ...
# 355  21237  Wolfe County      Kentucky  Computer in the Home
# 356  21237  Wolfe County      Kentucky  No Computer in the Home
# 357  21239  Woodford County   Kentucky  Computer in the Home
# 358  21239  Woodford County   Kentucky  Computer in the Home
# 359  21239  Woodford County   Kentucky  No Computer in the Home
#
#                   status  B28009A  B28009B  B28009H  B28009I
# 0    Broadband Access     12763.0  234.0    12554.0  261.0
# 1    No Broadband Access  1879.0   0.0      1876.0   3.0
# 2    No Broadband Access  2400.0   221.0    2348.0   52.0
# 3    Broadband Access     14563.0  43.0     14323.0  312.0
# 4    No Broadband Access  2697.0   105.0    2640.0   57.0
# ..                   ...     ...     ...       ...    ...
# 355  No Broadband Access  445.0    0.0      422.0    23.0
# 356  No Broadband Access  1402.0   0.0      1402.0   0.0
# 357  Broadband Access     20972.0  628.0    19848.0  1398.0
# 358  No Broadband Access  1581.0   208.0    1395.0   186.0
# 359  No Broadband Access  1304.0   285.0    1192.0   164.0
#
# [360 rows x 9 columns]

# %%
arg1 = {'comp':  {'Computer in the Home': np.concatenate([np.arange(4, 7), np.arange(10, 13), np.arange(16, 19)]), 'No Computer in the Home': np.array([7,13,19])     }   ,
        'status':  {'Broadband Access': np.array([5, 11, 17])       , 'No Broadband Access': np.array([4,6,7,10,12, 13, 16, 18,19])   } }
table2 = acs.gen_subgroups(arg1, groups =['B28005'])
table2
# Out:
#       FIPS           County      State                     comp  \
# 0    21001  Adair County      Kentucky  Computer in the Home
# 1    21001  Adair County      Kentucky  Computer in the Home
# 2    21001  Adair County      Kentucky  No Computer in the Home
# 3    21003  Allen County      Kentucky  Computer in the Home
# 4    21003  Allen County      Kentucky  Computer in the Home
# ..     ...           ...           ...                   ...
# 355  21237  Wolfe County      Kentucky  Computer in the Home
# 356  21237  Wolfe County      Kentucky  No Computer in the Home
# 357  21239  Woodford County   Kentucky  Computer in the Home
# 358  21239  Woodford County   Kentucky  Computer in the Home
# 359  21239  Woodford County   Kentucky  No Computer in the Home
#
#                   status   B28005
# 0    Broadband Access     13331.0
# 1    No Broadband Access  1879.0
# 2    No Broadband Access  2621.0
# 3    Broadband Access     15061.0
# 4    No Broadband Access  2802.0
# ..                   ...     ...
# 355  No Broadband Access  445.0
# 356  No Broadband Access  1437.0
# 357  Broadband Access     22489.0
# 358  No Broadband Access  1823.0
# 359  No Broadband Access  1641.0
#
# [360 rows x 6 columns]

# %%
table2.merge(table1, on = list(table2.columns[:5]))
# Out:
#       FIPS           County      State                     comp  \
# 0    21001  Adair County      Kentucky  Computer in the Home
# 1    21001  Adair County      Kentucky  Computer in the Home
# 2    21001  Adair County      Kentucky  No Computer in the Home
# 3    21003  Allen County      Kentucky  Computer in the Home
# 4    21003  Allen County      Kentucky  Computer in the Home
# ..     ...           ...           ...                   ...
# 355  21237  Wolfe County      Kentucky  Computer in the Home
# 356  21237  Wolfe County      Kentucky  No Computer in the Home
# 357  21239  Woodford County   Kentucky  Computer in the Home
# 358  21239  Woodford County   Kentucky  Computer in the Home
# 359  21239  Woodford County   Kentucky  No Computer in the Home
#
#                   status   B28005  B28009A  B28009B  B28009H  B28009I
# 0    Broadband Access     13331.0  12763.0  234.0    12554.0  261.0
# 1    No Broadband Access  1879.0   1879.0   0.0      1876.0   3.0
# 2    No Broadband Access  2621.0   2400.0   221.0    2348.0   52.0
# 3    Broadband Access     15061.0  14563.0  43.0     14323.0  312.0
# 4    No Broadband Access  2802.0   2697.0   105.0    2640.0   57.0
# ..                   ...     ...      ...     ...       ...    ...
# 355  No Broadband Access  445.0    445.0    0.0      422.0    23.0
# 356  No Broadband Access  1437.0   1402.0   0.0      1402.0   0.0
# 357  Broadband Access     22489.0  20972.0  628.0    19848.0  1398.0
# 358  No Broadband Access  1823.0   1581.0   208.0    1395.0   186.0
# 359  No Broadband Access  1641.0   1304.0   285.0    1192.0   164.0
#
# [360 rows x 10 columns]

# %% [markdown]
# ## Part V. Automate periodical updates
